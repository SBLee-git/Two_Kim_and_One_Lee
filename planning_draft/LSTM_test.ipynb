# %% [markdown]
# ## LSTM 머신 모델 테스트

# %%
import codecs
from bs4 import BeautifulSoup
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
import numpy as np
import random, sys, csv

# CSV 파일 읽기
csv_file = "new_indie.csv"  # CSV 파일 경로
text = ""

with open(csv_file, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        text += row[3] + " "  # 3 번째 열의 데이터를 이어붙임

print('코퍼스의 길이: ', len(text))

# 문자를 하나하나 읽어 들이고 ID 붙이기
chars = sorted(list(set(text)))
print('사용되고 있는 문자의 수:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))  # 문자 → ID
indices_char = dict((i, c) for i, c in enumerate(chars))  # ID → 문자

# 텍스트를 maxlen개의 문자로 자르고 다음에 오는 문자 등록하기
maxlen = 20
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('학습할 구문의 수:', len(sentences))
print('텍스트를 ID 벡터로 변환합니다...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# 모델 구축하기(LSTM)
print('모델을 구축합니다...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# 후보를 배열에서 꺼내기
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# 학습시키고 텍스트 생성하기 반복
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('반복 =', iteration)
    model.fit(X, y, batch_size=128, epochs=1)

    # 임의의 시작 텍스트 선택하기
    start_index = random.randint(0, len(text) - maxlen - 1)

    # 다양한 다양성의 문장 생성
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('--- 다양성 = ', diversity)
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('--- 시드 = "' + sentence + '"')
        sys.stdout.write(generated)

        # 시드를 기반으로 텍스트 자동 생성
        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 코퍼스의 길이:  447162
# 사용되고 있는 문자의 수: 1320
# 학습할 구문의 수: 149048
# 텍스트를 ID 벡터로 변환합니다...
# 모델을 구축합니다...
#
# --------------------------------------------------
# 반복 = 1
# c:\wanted_l\ML\env311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 54s 45ms/step - loss: 4.1561
#
# --- 다양성 =  0.2
# --- 시드 = "일 어쩔 땐
# 다른 생각도 못 해
# 나만"
# 일 어쩔 땐
# 다른 생각도 못 해
# 나만 가득 없어서 말해
#
# 그대가 내 밤이 가득 걸
# 내가 가득 말해
#
# 그대 내 마음 속에 있어
#
# 그대로 가득 말해
# 나를 가득 말해
#  그 가득 있어
#
# 우리가 가득 수 있을까
#
# 그대 내 마음 말해
# 내가 가득 말해
# 어디 가 가득 있어
#
# 그대가 나의 내 마음을 가득해
#
# 그대로 나를 가득 있어
#
# 우리가 나를 가득 걸 그대
# 나를 가득해 내 마음을 가득해
#
# 그대 내가 가득 말 말 걸
#
# 그대가 가득 너를 가득해
#
# 그대 너를 가득 있을까
#
# 그대로 가득 말 수 있을까
# 그대로 가득 수 있을 때 수 있어
#
# 그대 내가 가득 그 때 있어
#
# 우리가 너를 가득 때 가득 말 좋아
# 너를 가득 밤 그대가 있어
#
# 그대로 나 나 있어
#
# 그대 내 가득 있어
#
# 그대의 너의 밤 너를 가득 있고
#
# 우리가 좋아하는 너를 있어
#
# 나를 가득 말해
# 우리가 가득
#
# --- 다양성 =  0.5
# --- 시드 = "일 어쩔 땐
# 다른 생각도 못 해
# 나만"
# 일 어쩔 땐
# 다른 생각도 못 해
# 나만 내 다시 있어
# 내가 모르게 나 좋아
#
# 텨 그 걸 말 말 않게
# 나만 그대가 내가 그 살아
# 그대로 그대로 내게
# 매 내 더 가득 때 모습이 하나
# 내가 지나가 가득 말
# 그대 기억하게 걸 걸
#
# 아음은 가득 내리 사랑해
# 너를 위해 너를 수 있을까
# 우리가 가득 말 하루게 있어
#
# 그대로 나는 밤 것 맙게 가 가려가 나
#
# 그대로 나는 그리가 가득 하나가 있어
# 우리가 우리가 가득가 싶어
# 전에 우리가 나를 내리게 마
# 내게 사랑이 가는 봐
#
# 그렇게 가득 때 있어
#
# 아무 때러 가득 말 수 있는데
# 우리 없는 내 건 때
# 어디한 떠나가 돼
# 너를 마음이 다 좋아
# 돌아서 안 속에
# 지나가 가득 싶어
#
# 우리를 가득한 수 있고 싶어
# 내 밤이 가득 하루가 싶어
#
# 우리가 가득 위해 가는 걸
# 내 마음이 나를 있어
# 또 마음에 기억해
# 더 그대가
#
# --- 다양성 =  1.0
# --- 시드 = "일 어쩔 땐
# 다른 생각도 못 해
# 나만"
# 일 어쩔 땐
# 다른 생각도 못 해
# 나만는 말하다다득
# 롭써 것의 켜 같은
# 그대 것도 채번 날삽면
# s잖은 말다리 더 싶어, 나의
# 그러 누딛가 있어
# 율된하게 우까
# 마담 쉴 운될려가고 그팅앞을 심깄해
# 잠람은 우리가 세르던
# 가끔가 좋게 비리를 일을 팔은
# 렴섣 가고에 차마는 아땐 그대가 볼적자
# 민벽험라면 뇌
# 늘로 좋아 어맙면게 던 거리면
# 나가 그리게 하는 사랑이데
# 겼으니 때쪼가 그더 걸법많아 웃르루 걸
# 손고 쀼어 no 달ay ay sham the kall, ow
# 기억만만
# 내리기 매일
# 띠춰 살아
# I fas al 살eoraro fan
# 그대뿔지 비살살다 지나
# 다 난 하나 했어
# 자디에 수가나는고세고하면
# 모두 y었이 더 괴녕
# 꽉r엔둥고
# 정목하고 가움했죠죠
# 그때 어숙리게 돼야 비해 돼
# 너무 너를 좋회죠
# 런대로 약에가 맞은 거리까도 픈
# 약 작은 나조금
# 오르비까 아들다
#
# --- 다양성 =  1.2
# --- 시드 = "일 어쩔 땐
# 다른 생각도 못 해
# 나만"
# 일 어쩔 땐
# 다른 생각도 못 해
# 나만 일길를 말해자리가 뻔 수를 쏴기는 걸 하나게
# 이렁뱉었짓 괜효낼는 찾아보고
# 사랑해 O절 이 집어
# 뒀가학기가는는 러 달게
# 다시게요냐 생각하는 걸러줘
# 돌아가자.섣면 괜하다는
# 밤을친면 속각우리봐
# 네가요고 한늘다면면 참 해
# 시제
# 일볕씹년 달공기
# 닿얘이군고줘 워물은'써
# 납까까 꼭 기르예말면
# 착청꼬가고 싶으휩 싶어
# 일썰대곧리해멸던 자대니까가
# 너가 나을까, 걸어
# 갈i원팍규는 U들은 비계좋것듯고준고놨 있어 않구지자
#
# 둠러고춥고 좋해가돼밤은
# 마음래가게탄일란볼기기해서
# F똑g막
# 참날력펼은할 띈제죠 빴낡
#  꿈은
# 하루맬게 서’기는 너의 첫혹
# 써딜X면 거리니려 게 부섯다  y
#  닿름기울려가끔피빛부고데
# 변쁨 춥슈 련 s냄
# 더린 새컵지만업생벽고
#
# 나와 쥐헤어
# 히소랠겠던 잃해요요 그대가밤령해 말랐리를 수해가고찾고
# 오늘m 무왼느깍히기몸
#
# --------------------------------------------------
# 반복 = 2
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 50s 43ms/step - loss: 3.0217
#
# --- 다양성 =  0.2
# --- 시드 = "그날의 너는 참 차가웠었고
# 그렇게 우"
# 그날의 너는 참 차가웠었고
# 그렇게 우리 나를 보면
#
# 어차가 가고 있어
#
# 우리 나의 마음이 되어
#
#
#
# I can love you love you love you love you love you love you love you
#
# I want a love you
#
# Love love you
#
#
# I can love you and the be love you
#
# I can love you
# I can love you feel you day
#
#
# I wan love you love you love you love you love you love you love you
#
#
# I can love you love you love you love you
#
# Love you love you love you love you
#
# I wan love you love yo
#
# --- 다양성 =  0.5
# --- 시드 = "그날의 너는 참 차가웠었고
# 그렇게 우"
# 그날의 너는 참 차가웠었고
# 그렇게 우리
# 사랑에 이 no me
# 그대 아무 말아
#
# 어둠이 사랑하지 않아
# 그 우리 나는 모두 게 있어
#
#
# 이제운 모든 게 다 전부 기
# 이 사랑이 돼
# 여전히 사랑하면 보면
# 그대 어쩌면 나는 사랑
# 마음이 끝이 모두 어디에
#
# 이제 내 맘 감고 싶어
#
#
# Love you no love a lake the live the live you
#
# Rame neel you love the say
#
#
#
#
# 하루 나는 사랑
# 나를 보면 가는 게 나
# 밤이 사랑하지 않아 난 해
#
# 그대 모두 해 난 그 왜
# 이제 어차 마 못 하는 게 모르게 안 줄 수 있어
#
# 우리 내 맘 너도 나고 있어
# 널 더 어쩌워 그 곳에
#
# 어둠 속 지나 내 맘 알고 있어
#
# 사랑이 나 아니야
# 아닌 이 마음
# 나 이제 다 져 마
#
# 우리 이 날 나에게
#
# 너를 만나 아닌 아무 테
#
# --- 다양성 =  1.0
# --- 시드 = "그날의 너는 참 차가웠었고
# 그렇게 우"
# 그날의 너는 참 차가웠었고
# 그렇게 우네 그대고 하던 날 좋아하는 게 가횐 손처럼
# 한전한 행복하게 끝을 때게 보고 길을게
# 팥고 뻗는 옛요만 있해
# 내 마음에 콜소던 그곳에
# 뻗원한 잃기를 취안게 공따라
# 다른 이제 텨근워
# 내 전 이 똑김아한 모습 는  게
# 아질 달스랖인게 짝다다 보
#
# 그래에 왕땠 솔에
# 다l알럼가
#
#
# And me fee als forela love alove
# 나는 사랑을 안하고 있어 wille f Bale
# Love you 현lll be all tho forey bed
# anay day? d ada talke a len tare you 號une lett
# Sove no
# Holl s懂y ure flee 네 시간달
#
# I steake bus? daye u매le
# 긴 폭붙에 날 하고
# 세러한 것 마음아찔 해 봐
# 그대에 찬그대로
#
# 가끔나 자귓들했던
#
# --- 다양성 =  1.2
# --- 시드 = "그날의 너는 참 차가웠었고
# 그렇게 우"
# 그날의 너는 참 차가웠었고
# 그렇게 우곳 껌Y러 우릴 찾강리고
#  )섦F팝
# 참붕켓어전 며엇에깔 우 배고
# 내 파랐던화 ic씬l 전lay?
# 랜복밤한 이 고홍겠 가 툰대게
# 웃으아출게 (니 위에 으실 만들지만 해로는
# 척
# 핏어협네고 것 처럼 s뱀i벅 aw
# 난
# 아셋 곤태줄 수해
# 답춰후’은 다 마치듬 해
# 난 번 푸找진 뼈보여
# 심h치자 즐밝은 조인빠스율찡 겁안내데 낭작은 지구지
# 구낡히 요뜀지 못할귀뜯박릴 그저
# 지뚤쉿어운 근까릿일
# 죽대를 오쌓구해슨운 날
# 넌 노력질을 추곡듯
# 어판서 너의 거야밥서가요
# 가란히 아이었는 물
# 우리, 날은로만
# 오늘들으는 별들에게 비밝있게 잖은 수 있을 수 있늘냐
# 하7뿐을 시작 k변기 돌아서
# eywe- ho범봐g
# We rack 냬차m 난 ?)
# S히 갛할 순데
# 난 통좇네 가間함,
# 듬u들게 night
# 그핼태던 먼얼
# 그 여H던 내 미울 문지
#
# --------------------------------------------------
# 반복 = 3
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 47s 40ms/step - loss: 2.7598
#
# --- 다양성 =  0.2
# --- 시드 = " 참 보고 싶어요
# 오늘은 그대 내 곁"
#  참 보고 싶어요
# 오늘은 그대 내 곁에 있는데
#
# 그대 나를 보내고
# 너를 가는 것처럼
# 그대로 내가 나는 나를 보면 말해
#
# 너의 이렇게 나를 가득해
#
# 그대 나를 보면 내 맘이 가득 수 있어
# 그대 나를 보면 내 맘을 가득 수 있어
#
# 너의 이렇게 그대로 나는 아니 거리 없어
#
# 너를 보면 내 맘을 가득 수 있어
# 그대 나를 바라봐 나는 말이 있어
#
# 너를 가는 것 같아
# 그대 나는 이렇게 없는데
#
# 너의 마음을 사랑해
# 그대 나를 가는 것들을 바라
#
# 그대 나를 가는 것들이 있어
#
# 너를 보면 나를 가고 있는 것 같아
# 그대 나를 보면 내 맘이 되어 내 맘이 가득 수 있어
#
# 그대 나는 이 말도 없는 게 아니 거리
#
# 너를 어디 어디로 없는데
#
# 그대 나를 사랑해 안 아니면
#
# 나를 보면 그대 없는데
#
# 그대 나를 안아 해 안아 해
#
# 너를 보내고 있는데
#
# 그대 나는 말들이
#
# --- 다양성 =  0.5
# --- 시드 = " 참 보고 싶어요
# 오늘은 그대 내 곁"
#  참 보고 싶어요
# 오늘은 그대 내 곁에 없는데
# 너 나를 보면 마음 수 없는
# 사랑이 아니 마음 수 없는 거야
#
# 그대를 나면 나를 줘요
# 내일 나를 알아 말해
# 그대 나를 보내게 해도 가는 게 아는데
#
#
# 그대 없는데
# 나를 지나가 가는 걸음에 사랑하고 날 바라봐
# 우리의 이 밤이 통리는데
#
#
# 너를 바라봐 해
#
# 너무 아니 you saind
# 나는 아름은 날 그렇게
# 너를 보면 말해 너를 그렇게
# 오늘이 내게 해져 나를 가고 있는데
#
# I never the waiter sur
#
# I see in the with with thing
#
# I feel be with me the stilling
#
# I stee mething to still you
#
# 아름다운 내 마음이 내게로
# 그대로 나를 보면 해도 나만 아니야
#
# 그렇게 모르게 더 내가 나면 나를 바라봐
#
# 그대에 내 맘이
#
# --- 다양성 =  1.0
# --- 시드 = " 참 보고 싶어요
# 오늘은 그대 내 곁"
#  참 보고 싶어요
# 오늘은 그대 내 곁에
# 찬란한 게 버릴 것 같은데
#
# 난 저리는 내 마음을 것에 해
#
# 그대 그닌몹이 있는 늘 알 하나를 있는 럼
# 내 세상에도
# 너시의에 별을 안아 멜말 없고
# 지금 X를 's 태우기가
#
# 새빛이 나의 게 줘요
# 밤이 같은 너를 사랑이 ?하는데
# 너는 도가도가 버o입 오니까
# 이렇게 그대까지 나
# 나를 니가 난
# 그대에 있면요
# 파도 울빛나 a녕 나서 보내가 떠길지 않아
# 눈빛 줘 겁다있어 like
# With tud is towine
# 걸는것도훨의 숍걸음까
# 전할 건 비추워는데
# Justle side don't푼e ever dight
# anoattides you ever see,
# dand see back awkill not씬 (더 어디깨네
# 널 좀낼다 떠나생지만 해도
# 그대? 기다 이렇게 H명하는 생각딸둠
# 언말변에 내 어느물라던 불인이 둡여야
#
# --- 다양성 =  1.2
# --- 시드 = " 참 보고 싶어요
# 오늘은 그대 내 곁"
#  참 보고 싶어요
# 오늘은 그대 내 곁에서 해
# 너를 고섯면서
# 함께난겁으면
# 네가 내 담다라
# 날 수 없 게가 톡관 잡고 비딨데
# 앞로의 말기치 하는시터
# 언렇게시을 했는데
# 이젠할것이 자꾸급
# ca6 같이 맴엉맛想
# 길어무만 날은 혼모이 있기를 요프보지
# 난 더 바라보면 그렇아요이 난 몇지손 없는걸
# 맞현새러가줘
# 서하게 너와 늘 나를 땐거리 가만귀서 날에볼고갔해봐
# 빰마족을 깽아
# 고마나 를 피b하게 걸지같슨 미굣 머닥매
# M운 사람이 반궐일이잖도
# 채차가라s잤라 왜 아냥엄이
# 계횐 한시에서 없어도 내도 i생종prillding탔, 날 가딨짱린냐
# 마난 것의
# 잊았해
# 네가 걱눈기 없는데도
# I'화 바라오질고 던득 완줌해
# 녈 노뜩줍일두 그대의 말새까, 당동훈는데
# 저 주쳐만v 골힌거로
# 너의 바다마릿r 해주고E돌또 져요
# 이올릴겐 수맘 버릇했던 지나한 오늘도 적젯해요도 g스t테他
#
# --------------------------------------------------
# 반복 = 4
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - loss: 2.6155
#
# --- 다양성 =  0.2
# --- 시드 = "힌 그대라는 별 비밀이 없기로 해 우"
# 힌 그대라는 별 비밀이 없기로 해 우리 이 밤이 나 내 맘을
#
# 너의 밤 같은 밤
#
#
# 우리 속에 있었어
#
# 나는 내 맘을 다 다 다 아닌 거야
#
# 나는 너의 마음을 보낼 거야
#
# 나는 내 맘을 다 다 다 다 아픈 어떤 것 같아
#
#
# 너의 하루가 나 내 맘을
# 너의 밤을 지나고 해
# 너도 나 나 아직 너에게 나 나 아직 너의 밤
# 그대 나의 말이 나 내 맘을
#
# 너의 곁에 있는 것 같아
#
# 나는 그 밤이 나 나를 생각해
# 내 맘을 다 내 맘을 가는 나
# 내 맘을 다 내 맘에
# 너도 나 아직 날 아닌 거야
# 우리 속에 있는 것 같아
#
# 나는 내 맘에 나 아직 너에게
# 나도 내 맘을 다 버린 거리에
# 나의 꿈을 보이 나는 나 아직 나는 나 아직 어디로
#
# 나는 나 나의 그 밤이 나 나의 말이
#
# 우리 속에 있는 것 같아
# 내 맘을 다 가득
# 너의 밤 이 밤에
#
# 우리
#
# --- 다양성 =  0.5
# --- 시드 = "힌 그대라는 별 비밀이 없기로 해 우"
# 힌 그대라는 별 비밀이 없기로 해 우리 어둠이 나 내 맘에
# 다 지경 거라도
# 내 맘이 내 맘에 멀리 난 아름다운 말 어딘다
# 더 아직 난 나의 모습이 나 가져서
# 난 아직 이 기억이 나 나는 내가 내 맘을 보고
#
# 하루만 내 맘을 도 못 해
#
# 오직 내 맘을 따라서
# 나의 말이 나를 바라보는 것도
#
# 나도 나 아직 나는 너의 곁에 있는
# 이 안에 대신 속에서
# 너의 모습 속에서 내 맘을
# 이 길을 기억이 아닌 말이야
# 내 손을 띄아 지금은 나는 나 아닌 말이 하는 난
# 그대의 너의 밤
# 하는 날 바다에 나 이 노래가
# 우리 둘 이 밤
#
#
#
#
# 너는 나의 말 속에
# 아직도 난 아직 날 아닌 기억이 그리워
# 내 맘을 내게 해
# Hight is you been in the cook
#
# Held been is you bean
# I won't gonna be up
# we te
#
# --- 다양성 =  1.0
# --- 시드 = "힌 그대라는 별 비밀이 없기로 해 우"
# 힌 그대라는 별 비밀이 없기로 해 우리 한 q을 버릴까
# 오쉰다고 긴런서각이 그러여
# 후어서 nep my eveer peery p상cry
# Yof dee in upus to stay
# Been 나도 같이 i라'm me away
# You're light a 두fory
# 안 o퍼b day me chinoming
# 하루앞장원이 나는 우리 속을 알아서 라두밤을 멀약요
# 우리 계절에 내 바래
# 셀 힘이 난 릴 거라는 까
# 이별도 넌 이젠 더 잠파 버릴 거라도 노쁜
# 낙진 할 사이에
# 나알은 너의 손을 감얼옛야
# 이름을 틱 어려가 난 나지고 싶잖아
# 내 밤은 날 넷묻다고 싶을 말 무대까
#
# 울시가 2 눈을 위해 달스I 못 나서 뭐 말은 나가서컴 가는 그림에
# 전부웁이 좋아서도 다른온다시요 무 원에
# 다가올은 늘 아래도 s란 titon
# 언제나 난 네가 있지만
# 하내도 턱 들이 하기 길
#
# --- 다양성 =  1.2
# --- 시드 = "힌 그대라는 별 비밀이 없기로 해 우"
# 힌 그대라는 별 비밀이 없기로 해 우린 의삭디거부할
# 야활만 끔작는다를 촉하어내 신을 후물 할 저
# 우리 F정말아두네 언킬이라기가
# 눈물로 다습녜 줘서 특찾네 그뭇일 사랑한!잖아양
# 우는 같은 세에지는 우린 미핸이 돼줄게
# 갓 콩늙인가 싼옥러리다W딸요 한 숨에 너긴 어경겠지는 켓녜
# 날 시턴해 조끝이 있었나 e항않
# r뎌ug dount콩r myfmer (에도 멎구한쟨
# Yeah 록k까남자昨혀
# I cere yeah night
# 난 i- ride
# 곧에 곱캔을 슬랩주랍과 텐데
# 이침람해가 우린 나는 있겠지만
# 나는 춥사의 m존가는 하늘에도랩o쩜 and day
# S! remings
# 집을 가보새 사 들가는
# 던집에추를 가득이 안[ 볼 수 있잖아
# 언제좋닳을 빛웁고 반길태었어 널 사랑을 해울 a세
# I fald
# 지 애써 대즘 찌학겠지만
# 행복한 하루가 싶어도 마
# G텐의 이냐고
#
# --------------------------------------------------
# 반복 = 5
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 43s 37ms/step - loss: 2.5232
#
# --- 다양성 =  0.2
# --- 시드 = " 이유 없는 사랑을 해 너는 모를 거"
#  이유 없는 사랑을 해 너는 모를 거야
#
# 아무 말해 내 곁에 있어
#
# 너를 보면 내 마음이 나 어디로
# 아무 말해 안 돼
#
# 아무 말해 네 마음 안 돼
#
# 너를 보면 나 내 곁에 있어
#
# 아무 말해 안 돼
#
# 이제 내 곁에 있어 내 마음을 보고 싶어
#
# 이제 내 곁에 있어 내 맘
#
# 아 한 번 그 밤 이 밤
#
# 너를 보면 좋아
#
# 아무렇지 않았는데
#
# 아무렇지 않았지 말해
#
# 너의 하늘 아래 너의 이 밤이 좋아
#
# 이 밤 너의 마음이 내게로
#
# 아무렇지 않았는데
#
# 아무 말해 너와 나
#
# 이제 내 곁에 있어 내 맘
#
# 너를 보면 좋아
# 아무 말해 나 내 곁에 있어
#
# 이제 내 곁에 있어 내 마음 안 돼
#
# 그 밤 같은 이 밤 너를 좋아하는 거야
#
# 아무렇 기다려 해 안 돼
#
# 아니 이 밤 너를 좋아하고 싶어
#
# 그대 내 곁에 있어 내 맘
#
# 아 하는 밤 너의 이 밤이
#
# --- 다양성 =  0.5
# --- 시드 = " 이유 없는 사랑을 해 너는 모를 거"
#  이유 없는 사랑을 해 너는 모를 거야
#
# 아무렇는 것 같아 이 밤이 지나가
#
# 이제 내 곁에 있어 지난 거야
# 우리 이제 똑같이 나는 그 거야
# 내 몸 그리 그 vow can wand you are
# You love you storent lover city
# I been I can I love you do
# I tanter it all the sain
# The sure you nothing
# 나를 보고 있는 거야
#
# 아무 말해줘
# 이제 어디로 가는 걸
# 아무 말해 너는 좋아
# 나는 내 맘 그리 내 맘 그리 해
#
# 그 이름 속에 내 맘
#
# 언제 함께 내 곁에 있어서
# 이 밤 수 없는 게 내게로 나 오래 너와 Oh
# I can't lovely no one you love you say and now
# I can love you love me but you wanna die
#
# --- 다양성 =  1.0
# --- 시드 = " 이유 없는 사랑을 해 너는 모를 거"
#  이유 없는 사랑을 해 너는 모를 거야
# 이젠 넌 특별 없이 곁엔
# 모른 순간에서 내 그비 알았나?
# But Kin love so never cominn
# 사랑하늘도 않았룩요
#
# 낙움은 찬테싶을 때
# 오늘 앉은 비 쪽고
#
# 난 너의 번만
# So have you
# when I courden you and ruteld rong mine
# 어제 내 마음을 달콤히
#
# 미안을 말해요
# 깜건너는 끝이 좋아있어
#
# 나를 따라 불염어
# (하 텼장 속길 나면서 'le힌end 청를 갔어
# Oh
# I won't over, with youn no does brean inty a tre
# 도망에 부잉밤 너야 우리만 잘 좋아요
# 씌전부은 필요 Sw!er 거리라
# 댓보고 싶어
# 이 음 밤 손 Eacd fale
# Seecell i의 up triig
# But some s곰ef looker one
# 이제 국 몸을
#
# --- 다양성 =  1.2
# --- 시드 = " 이유 없는 사랑을 해 너는 모를 거"
#  이유 없는 사랑을 해 너는 모를 거야
#
# y댄u첨 How
# do blecihes rechresesenin 어엉왕맘 널 바라떠
# "매척이 어有립다흘 버울껄 물들을까
# 액망한 날동보여
# 오늘희진긴 예쓱폰들 사이 사벅떠 너를 었활해 이렇지
# 둘았는 머릿마붕저 씹새w흐 한 동m중
# 순착이T속시 엊데
# 난 If you fa꿨e, i빼 lown
# 1억 꽤 너만 킨 란기야
# 이랬인온 하더만 어h깜 Mode
# Iffe덩ly suat
# 듯해 co쩔e
# lost랄i잿
# i love yever negnt깍s
# 밍컷 작은 ar푹absem 멘판, 나 바황로 될 사라
# thould I적 bun for not)
# 툭자따 젠요U
# You honningrinit콘
# You in you loke 난 특올빛으니했신계 쌀집했어
# 헤추어도 웃녕, 했h명게소소녕피지만 내 지냈롯고선
# 까살았이여히 우라 엑들었어
# Bu
#
# --------------------------------------------------
# 반복 = 6
# 1165/1165 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - loss: 2.4497
#
# --- 다양성 =  0.2
# --- 시드 = " you so
# 네가 너무 보고 싶어
# "
#  you so
# 네가 너무 보고 싶어
#
# I want you like me to loon
# I'm to the stor things for you
# I'm the so love you like you
# I'm to be with me my life
# I'm the be arronl me now
# I want you becars
# I'm the so love you
# I want you been the stor think
# So lonelecs a star think
# I'm the so lonely love me to me now
# I'm the don't want a day
# I'm the so love you love me now
# I'm the so love me bettin the sound with me best with you
# I'm to the so lo
#
# --- 다양성 =  0.5
# --- 시드 = " you so
# 네가 너무 보고 싶어
# "
#  you so
# 네가 너무 보고 싶어
#
# I'm conlle a sack it a sass
# I'm the sed is my bells
# I want you be prom and but spor
#
# Fast dars in my eyes with me to bleat
# I'm that it bout the susting
#
# I'm to bad you want to that with I want you
#
# I'm the on the stor and it a don't can do
# I'm that with you to me
# I do I do love me you
# 너에게 아직 사랑이 가는 거 같은 거야
#
# 지금 이 별을 보이는 너의 마음을
# 난 아직 너의 달인 게 있어
# 내게 가사를 던져 지나
# 내 마음을 마주치고 싶은데
# 이 밤이 내게 너를 만나서
# 어디 아무도 않아
#
#
# --- 다양성 =  1.0
# --- 시드 = " you so
# 네가 너무 보고 싶어
# "
#  you so
# 네가 너무 보고 싶어
# 난 아니다 긋한 말으로
# 네게 가기칙가까
# 오늘 밸다 잊으니 두빴할 땐
# 둑못했던 것 같은 맘 피곤
# 시간 기다고 난 어릴 네게 예쁜 걸
#
# 너하게 하나
# 오늘도 못했던
# i Xlistin'? I cang my fly?
# Sh on lont
# 그렇게 함께 줘도 좋아
# when a hod you wannay
# 설쯤쩐가
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 91
#      88 for t, char in enumerate(sentence):
#      89     x_pred[0, t, char_indices[char]] = 1.
# ---> 91 preds = model.predict(x_pred, verbose=0)[0]
#      92 next_index = sample(preds, diversity)
#      93 next_char = indices_char[next_index]
#
# File c:\wanted_l\ML\env311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:
